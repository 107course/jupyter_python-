# %%
import requests
from bs4 import BeautifulSoup
res = requests.get("http://www.xinshipu.com/zuofa/49391")
#print(res.text)
soup = BeautifulSoup(res.text,'lxml')
print(soup)
print("==================================")
#print(soup.select('.content')[0])
reup = soup.select('.re-up')
print(reup.select('.cg2.mt12'))
#print(reup.select('.cg2.mt12 span:nth-of-type(2)')[0].text)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">
# <html>
# <head>
# <meta content="散寿司,散寿司的做法,散寿司怎么做" name="keywords"/>
# <meta content="1.将甜豆洗净、去蒂，汆烫熟备用；萝卜婴洗净，泡水备用。2.鲜虾洗净去肠泥，用竹签从虾尾部分沿背瘠贯串，放入热水中汆烫熟后，再取出竹签，去头去尾，剥除壳备用。" name="description"/>
# <title>散寿司的做法_散寿司怎么做_散寿司的家常做法【心食谱】</title>
# <meta charset="utf-8"/>
# <meta content="zh-CN" http-equiv="Content-Language"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width" name="MobileOptimized"/>
# <meta name="google" value="notranslate"/>
# <meta content="no-siteapp" http-equiv="Cache-Control"/>
# <meta content="mobile" name="applicable-device"/>
# <link href="http://xinshipu.cn/2014/css/img/xsp.ico" rel="shortcut icon"/>
# <link href="http://xinshipu.cn/2014/css/img/touch-icon-iphone.png" rel="apple-touch-icon"/>
# <link href="http://xinshipu.cn/2014/css/img/touch-icon-ipad.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="http://xinshipu.cn/2014/css/img/touch-icon-iphone-retina.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="http://xinshipu.cn/2014/css/img/touch-icon-ipad-retina.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="http://xinshipu.cn/2014/css/xspxsp.highendmobile.20141015.min.css" rel="stylesheet" type="text/css"/>
# <style>
# .word-link-list li{padding: 18px 24px 18px 0;}
# #adBottom {
# left:0;
# position: fixed;
# text-align:center;
# bottom: 0px;
# width:100%;
# height:120px
# }
# </style>
# <script src="http://xinshipu.cn/js/inc.20151111.js"></script>
# <script type="text/javascript">
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#
#   ga('create', 'UA-11253628-8', 'xinshipu.com');
#
# 	ga('set', 'dimension1', 'control');
#
# 	ga('send', 'pageview');
# </script>
# <script>
# 			function isLogin(){
# 				var user =  eval({"is_login":0});
# 				return user;
# 			}
# 			var _config = {
# 				'isv_userinfo': function(){
# 					return isLogin();
# 				}
# 			};
# 		</script>
# </head>
# <body>
# <div class="w tc header" style="position:fixed;  z-index: 999;">
# <!--BEGIN TOP -->
# <div class="top">
# <div class="mlr4 h50">
# <div class="logo">
# <h1><a href="/" target="_self"><span>心食谱</span></a></h1>
# </div>
# <a class="search-fold" href="#q" onclick="document.getElementById('q').focus();return false;"><i class="icon-font icon-search"></i></a>
# <div class="fr menu-r"><a class="more-menu" href="#q"><span class="icon-menu"> </span></a></div>
# </div>
# </div>
# <!--END TOP -->
# <div class="w tl nav hideNav-new"></div>
# </div>
# <div class="content" itemscope="" itemtype="http://schema.org/Recipe">
# <h1 class="font16 h47 tc cg1" itemprop="name">散寿司</h1>
# <hr/>
# <div class="mlr1 mt14 new-menu-pic"><img itemprop="image" src="http://ama.xinshipu.cn/20110720/original/1311149422451.jpg@300w_225h_90q_1e_1c.jpg"/></div>
# <div class="p01bgf">
# <h2 class="subtitle cg1">材料</h2>
# </div>
# <div itemprop="ingredients">
# <p class="ptm12 mlr1 btm"><a class="orange-bottom" href="/zuofadaquan/83/" rel="CaiLiaoClicked" title="寿司饭做法大全"><span class="ingredient"><span class="name">寿司饭</span></span></a>适量，<a class="orange-bottom" href="/zuofadaquan/1350/" rel="CaiLiaoClicked" title="鲜虾做法大全"><span class="ingredient"><span class="name">鲜虾</span></span></a>4尾，<a class="orange-bottom" href="/zuofadaquan/3603/" rel="CaiLiaoClicked" title="鲔鱼做法大全"><span class="ingredient"><span class="name">鲔鱼</span></span></a><a class="orange-bottom" href="/zuofadaquan/8221/" rel="CaiLiaoClicked" title="生鱼片做法大全"><span class="ingredient"><span class="name">生鱼片</span></span></a>适量，<a class="orange-bottom" href="/zuofadaquan/1977/" rel="CaiLiaoClicked" title="鲑鱼卵做法大全"><span class="ingredient"><span class="name">鲑鱼卵</span></span></a>适量，市售<a class="orange-bottom" href="/zuofadaquan/5992/" rel="CaiLiaoClicked" title="蒲烧鳗做法大全"><span class="ingredient"><span class="name">蒲烧鳗</span></span></a>1/2条，<a class="orange-bottom" href="/zuofadaquan/8815/" rel="CaiLiaoClicked" title="厚蛋烧做法大全"><span class="ingredient"><span class="name">厚蛋烧</span></span></a>3~5片，<a class="orange-bottom" href="/zuofadaquan/5373/" rel="CaiLiaoClicked" title="干瓢做法大全"><span class="ingredient"><span class="name">干瓢</span></span></a>煮各适，<a class="orange-bottom" href="/zuofadaquan/3735/" rel="CaiLiaoClicked" title="蒟蒻做法大全"><span class="ingredient"><span class="name">蒟蒻</span></span></a>煮适量，<a class="orange-bottom" href="/zuofadaquan/1129/" rel="CaiLiaoClicked" title="小黄瓜做法大全"><span class="ingredient"><span class="name">小黄瓜</span></span></a>片少许，绿<a class="orange-bottom" href="/zuofadaquan/21/" rel="CaiLiaoClicked" title="紫苏叶做法大全"><span class="ingredient"><span class="name">紫苏叶</span></span></a>适量，<a class="orange-bottom" href="/zuofadaquan/26/" rel="CaiLiaoClicked" title="酱油做法大全"><span class="ingredient"><span class="name">酱油</span></span></a>适量，<a class="orange-bottom" href="/zuofadaquan/1441/" rel="CaiLiaoClicked" title="鲑鱼做法大全"><span class="ingredient"><span class="name">鲑鱼</span></span></a>生鱼片适量，<a class="orange-bottom" href="/zuofadaquan/4607/" rel="CaiLiaoClicked" title="虾卵做法大全"><span class="ingredient"><span class="name">虾卵</span></span></a>适量，<a class="orange-bottom" href="/zuofadaquan/8148/" rel="CaiLiaoClicked" title="香菇做法大全"><span class="ingredient"><span class="name">香菇</span></span></a>煮适量，<a class="orange-bottom" href="/zuofadaquan/8375/" rel="CaiLiaoClicked" title="红萝卜做法大全"><span class="ingredient"><span class="name">红萝卜</span></span></a>煮适量，<a class="orange-bottom" href="/zuofadaquan/4567/" rel="CaiLiaoClicked" title="寿司姜做法大全"><span class="ingredient"><span class="name">寿司姜</span></span></a>适量，<a class="orange-bottom" href="/zuofadaquan/684/" rel="CaiLiaoClicked" title="甜豆做法大全"><span class="ingredient"><span class="name">甜豆</span></span></a>适量，<a class="orange-bottom" href="/zuofadaquan/285/" rel="CaiLiaoClicked" title="萝卜做法大全"><span class="ingredient"><span class="name">萝卜</span></span></a>婴适量，<a class="orange-bottom" href="/zuofadaquan/2336/" rel="CaiLiaoClicked" title="酪梨做法大全"><span class="ingredient"><span class="name">酪梨</span></span></a>丁适量，<a class="orange-bottom" href="/zuofadaquan/4822/" rel="CaiLiaoClicked" title="山葵酱做法大全"><span class="ingredient"><span class="name">山葵酱</span></span></a>适量</p>
# </div>
# <div class="p01bgf" itemprop="recipeInstructions">
# <h2 class="subtitle cg1">做法</h2>
# </div>
# <div class="pm12">
# <div class="mlr1 bbm">
# </p>
# <p> </p>
# </p>
# <p>3.将寿司饭盛入容器内，再将全部材料依喜好摆放在饭上即可，搭配酱油与山葵酱一起食用。</p>
# <center>
# <script async="" src="http://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 移动广告 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1301161247680439" data-ad-slot="2554907909" style="display:inline-block;width:300px;height:250px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </center><hr class="mt20"/>
# <div class="clearfix store-block">
# <div class="fl">
# <div class="h-pw clearfix mt12">
# <a class="cb" href="/chufang/1151/" rel="nofollow">
# <img class="photo24" src="http://ama.xinshipu.cn/css/img/nophotobig.jpg@24w_24h_99q_1e_1c"/>
# <span itemprop="name">美食小当家</span>
# </a>
# </div>
# <span itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <span itemprop="ratingValue">4.5</span>分
#           			<span itemprop="reviewCount">6</span>位评价
#       			</span>
# </div>
# <input id="bookmarked" type="hidden" value=""/>
# <input id="anonymityFavorites" type="hidden" value=""/>
# <form action="/api/doShouCang.html" id="searchform" method="get">
# <input id="shipuid" name="shipuid" type="hidden" value="49391"/>
# <input id="shipuname" name="shipuname" type="hidden" value="散寿司"/>
# <div class="fr"><button class="o-btn store-menu" type="submit">收藏食谱</button></div>
# </form>
# </div>
# <hr class="mt20"/>
# </div>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">相关食谱</h2>
# <div class="scroll-pic mt-12">
# <ul class="col3 relate-menu">
# <li>
# <a href="/zuofa/146960" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="日本五目散寿司" src="http://ama.xinshipu.cn/20120327/original/1332851100577.jpg@196w_126h_90q_1e_1c.jpg" title="日本五目散寿司"/>
# <div class="v-pw-w">日本五目散寿司</div>
# </div>
# </a>
# </li><li>
# <a href="/zuofa/150923" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="五目散寿司" src="http://ama.xinshipu.cn/20120517/original/1337213634065.jpg@196w_126h_90q_1e_1c.jpg" title="五目散寿司"/>
# <div class="v-pw-w">五目散寿司</div>
# </div>
# </a>
# </li><li>
# <a href="/zuofa/49011" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="和风星鳗散寿司" src="http://ama.xinshipu.cn/20100421/original/1271780125812.jpg@196w_126h_90q_1e_1c.jpg" title="和风星鳗散寿司"/>
# <div class="v-pw-w">和风星鳗散寿司</div>
# </div>
# </a>
# </li></ul>
# </div>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">推荐食谱</h2>
# <div class="scroll-pic mt-12">
# <ul class="col3 relate-menu">
# <li>
# <a href="/zuofa/68586" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="综合寿司" src="http://ama.xinshipu.cn/20100506/original/1273150567828.jpg@196w_126h_90q_1e_1c.jpg" title="综合寿司"/>
# <div class="v-pw-w">综合寿司</div>
# </div>
# </a>
# </li><li>
# <a href="/zuofa/265" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="水滴寿司" src="http://ama.xinshipu.cn/20100228/original/1267365654127.jpg@196w_126h_90q_1e_1c.jpg" title="水滴寿司"/>
# <div class="v-pw-w">水滴寿司</div>
# </div>
# </a>
# </li><li>
# <a href="/zuofa/65926" rel="ShipuInGridClicked">
# <div class="v-pw">
# <img alt="小白兔寿司卷" src="http://ama.xinshipu.cn/20100506/original/1273130362515.jpg@196w_126h_90q_1e_1c.jpg" title="小白兔寿司卷"/>
# <div class="v-pw-w">小白兔寿司卷</div>
# </div>
# </a>
# </li></ul>
# </div>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">美食问答</h2>
# </div>
# <div class="btm">
# <ul class="mlr1 word-link-list">
# <a href="/question/13217"><li>做寿司里面的食材除了青瓜、肉松、沙拉酱，还能放点什么？</li></a>
# <div class="bbt"></div><a href="/question/11637"><li>做寿司的竹简一般在哪里有卖，紫菜是哪种？</li></a>
# <div class="bbt"></div><a href="/question/14059"><li>做寿司应该用什么米煮的米饭</li></a>
# <div class="bbt"></div><a href="/question/5783"><li>我觉得一番寿司的土豆泥和好吃，求制作教程，万分感谢</li></a>
# <div class="bbt"></div><a href="/question/11505"><li>寿司醋在哪买啊？自己能调吗？</li></a>
# </ul>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">小知识</h2>
# </div>
# <div class="btm">
# <ul class="mlr1 word-link-list">
# <a href="/zuofa/142547"><li>韩国卷饭vs日本寿司</li></a>
# <div class="bbt"></div><a href="/zuofa/138404"><li>寿司的七大好处与吃法</li></a>
# <div class="bbt"></div><a href="/zuofa/144644"><li>饭团和寿司的区别</li></a>
# <div class="bbt"></div><a href="/zuofa/143297"><li>寿司不宜与哪些同吃</li></a>
# <div class="bbt"></div><a href="/zuofa/116444"><li>日本寿司的由来</li></a>
# </ul>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">厨友分类</h2>
# <ul class="gb-link-list mt-12">
# <li><a class="fenlei" href="/caipu/35413/" trackinfo="1">散寿司</a></li>
# <li><a class="fenlei" href="/s/c8d5cfb5cab3/" trackinfo="2">日系食</a></li>
# <li><a class="fenlei" href="/caipu/1331/" trackinfo="3">寿司</a></li>
# <li><a class="fenlei" href="/s/c8d5baab/" trackinfo="4">日韩</a></li>
# </ul>
# </div>
# <div class="mlr1">
# <h2 class="subtitle cg1">相关搜索</h2>
# <ul class="gb-link-list mt-12">
# </ul>
# </div>
# </div>
# <div class="search-wrap" id="searchbox">
# <div class="search mlr1">
# <!--BEGIN SEARCH MOD -->
# <div class="search-mod">
# <div class="search-pannel">
# <form action="/doSearch.html" method="get" name="search" target="_top">
# <div class="search-btn">
# <button onclick="javascript:ga('send', 'event', 'header', 'QuerySubmit',$('#q').val());window.location.href='/doSearch.html?q='+encodeURI($.trim($('#q').val()));return false;" type="submit">搜索</button>
# </div>
# <div class="search-panel-fields">
# <label for="searchVal">
# </label>
# <div class="search-combobox"><div class="search-combobox-input-wrap">
# <input accesskey="s" class="search-combobox-input font16" id="q" name="q" type="text" value=""/>
# </div></div>
# </div>
# </form>
# </div>
# </div>
# <!--END SEARCH MOD -->
# </div>
# </div>
# <div class="footer-nav btm" id="footer_menu" name="footer_menu">
# <ul class="word-link-list mlr1">
# <a href="/%E8%8F%9C%E8%B0%B1%E5%A4%A7%E5%85%A8.html"><li>菜谱大全</li></a>
# <div class="bbt"></div>
# <a href="/%E5%AE%B6%E5%B8%B8%E8%8F%9C.html"><li>家常菜谱</li></a>
# <div class="bbt"></div>
# <a href="/question/"><li>美食问答</li></a>
# <div class="bbt"></div>
# <a href="/%E9%A5%AE%E9%A3%9F%E5%81%A5%E5%BA%B7.html"><li>健康食疗</li></a>
# <div class="bbt"></div>
# <a href="/chuyoufenlei/"><li>食谱分类</li></a>
# <div class="bbt"></div>
# <a href="/usertop/"><li>厨友排行</li></a>
# <div class="bbt"></div>
# <a href="/highendmobile2014/login.highendmobile.html?from=/zuofa/49391" rel="nofollow"><li>登录</li></a>
# <div class="bbt"></div>
# <a href="/highendmobile2014/registre.highendmobile.html?from=/zuofa/49391" rel="nofollow"><li>注册</li></a>
# <div class="bbt"></div>
# <br/><br/>
# <div class="tc">
# 						©2016 xinshipu.com, all rights reserved.
# 						</div>
# </ul>
# <br/>
# </div></body>
# <script src="http://ajax.googleapis.com/ajax/libs/jquery/2.0.3/jquery.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# document.cookie="window_width="+$(window).width();
# </script><script type="text/javascript">
# 		function getTrackInfo(link){
# 			return decodeURIComponent(window.location)+'|'+link.attr('trackinfo')+'|'+decodeURIComponent(link.attr('href'))
# 		}
# 		$('.fenlei').click(function(){
# 			ga('send', 'event', 'zuofa', 'FenLeiClk', getTrackInfo($(this)));
#   		});
# 	</script>
# </html>
#
# ==================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-d633eac34828> in <module>()
#       8 #print(soup.select('.content')[0])
#       9 reup = soup.select('.re-up')
# ---> 10 print(reup.select('.cg2.mt12'))
#      11 #print(reup.select('.cg2.mt12 span:nth-of-type(2)')[0].text)
#      12
#
# AttributeError: 'list' object has no attribute 'select'
